# %% [markdown]
# ***
# ***

# %% [markdown]
# #### Тестовое задание в ChemTech AI

# %% [markdown]
# ##### Исполнитель: Друзык Роман Богданович

# %% [markdown]
# ##### Задание
#  * Используя данные представленные по ссылке Train_Data_200k создать модель, нацеленную на прогнозирование значений параметров Target_1...4 по значениям Tag_1...79.
#  * После получения модели применить ее к тестовой выборке представленной в архиве ML_Data в файле test_data_100k и на основании значений Tag_1...79 получить прогнозы для параметров Target_1...4.
#  * Полученные прогнозы и топ-10 значимых тэгов направить в качестве результата в ответном письме.

# %% [markdown]
# ***

# %% [markdown]
# #### *Проведем анализ данных*

# %% [markdown]
# *Загрузим необходимы для построения модели библиотеки*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import plotly.graph_objects as go
import plotly.express as px
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostRegressor, Pool
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# *Загрузим обучающий тестовый датасеты*

# %%
train = pd.read_csv(r'C:\datasets\ChemTechAI\train_data_200k.csv')
test = pd.read_csv(r'C:\datasets\ChemTechAI\test_data_100k.csv')

# %% [markdown]
# *Посмотрим визуально на данные*

# %%
train.head(3)
# Out:
#             Unnamed: 0      tag1  tag2  tag3  tag4  tag5  tag6     tag7  tag8  \
# 0  2016-08-18 00:00:00  15.78042   NaN   NaN   NaN   NaN   NaN      NaN   NaN
# 1  2016-08-18 00:01:00  15.80157   NaN   NaN   NaN   NaN   NaN  53.0644   NaN
# 2  2016-08-18 00:02:00  15.68913   NaN   NaN   NaN   NaN   NaN      NaN   NaN
#
#    tag9  ...     tag74     tag75     tag76     tag77  tag78     tag79  \
# 0   NaN  ...  53.02723  66.30531  55.10297  73.65612    NaN       NaN
# 1   NaN  ...  53.05109  66.30098  55.11534       NaN    NaN       NaN
# 2   NaN  ...  53.06495  66.30359  55.09395       NaN    NaN  55.07365
#
#    target1  target2  target3  target4
# 0      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN
#
# [3 rows x 84 columns]

# %%
test.head(3)
# Out:
#             Unnamed: 0      tag1  tag2  tag3  tag4  tag5  tag6      tag7  \
# 0  2017-01-03 21:21:00  12.59972   NaN   NaN   NaN   NaN   NaN  45.27993
# 1  2017-01-03 21:22:00  12.65850   NaN   NaN   NaN   NaN   NaN       NaN
# 2  2017-01-03 21:23:00  12.69538   NaN   NaN   NaN   NaN   NaN       NaN
#
#        tag8  tag9  ...     tag70     tag71     tag72  tag73     tag74  \
# 0  43.13644   NaN  ...  37.63644  40.64410  53.44470    NaN  36.59567
# 1  42.98455   NaN  ...  37.69201  40.68030  53.43953    NaN  36.60715
# 2  41.87401   NaN  ...  37.71147  40.69286  53.42733    NaN  36.60194
#
#       tag75     tag76     tag77  tag78  tag79
# 0  64.47523  45.08920       NaN    NaN    NaN
# 1  64.48697  45.18127       NaN    NaN    NaN
# 2  64.48034  45.00529  75.84169    NaN    NaN
#
# [3 rows x 80 columns]

# %% [markdown]
# ***

# %% [markdown]
# *Посмотрим на количество пропусков в обоих датасетах, относительно общего размера датасета*

# %%
train_NaN_view = train.isna().sum().sort_values(ascending=False) / train.shape[0]
test_NaN_view = test.isna().sum().sort_values(ascending=False) /  test.shape[0]

fig = go.Figure()
fig.add_trace(go.Bar(
    x=train_NaN_view.index,
    y=train_NaN_view.values,
    name='Train DataSet',
    marker_color='indianred'
))
fig.add_trace(go.Bar(
    x=test_NaN_view.index,
    y=test_NaN_view.values,
    name='Test DataSet',
    marker_color='lightsalmon'
))
fig.update_layout(barmode='group', xaxis_tickangle=-45)
fig.show()
# Out:
# <div>
#
#
#             <div id="17fcb77e-d5a4-4abf-a8f4-33a118c88c1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("17fcb77e-d5a4-4abf-a8f4-33a118c88c1c")) {
#                     Plotly.newPlot(
#                         '17fcb77e-d5a4-4abf-a8f4-33a118c88c1c',
#                         [{"marker": {"color": "indianred"}, "name": "Train DataSet", "type": "bar", "x": ["tag4", "tag6", "tag9", "tag41", "tag5", "tag51", "tag40", "tag8", "tag73", "tag61", "tag62", "tag69", "tag37", "tag36", "tag79", "tag78", "tag77", "tag54", "tag50", "tag53", "tag7", "tag46", "tag19", "tag52", "tag2", "tag3", "tag44", "tag45", "tag48", "tag39", "tag38", "tag59", "tag10", "tag56", "tag58", "tag42", "tag49", "tag29", "tag28", "tag27", "tag26", "tag25", "tag24", "tag76", "tag23", "tag74", "tag22", "tag21", "tag30", "tag75", "tag72", "tag11", "tag20", "tag57", "tag32", "tag43", "tag55", "tag64", "tag47", "tag33", "tag65", "tag66", "tag31", "tag67", "tag68", "tag70", "tag71", "tag35", "tag34", "tag18", "tag16", "tag15", "tag14", "tag13", "tag12", "tag63", "tag60", "tag17", "tag1", "target4", "target3", "target1", "target2", "Unnamed: 0"], "y": [0.999575, 0.998135, 0.997965, 0.992965, 0.95132, 0.92639, 0.92211, 0.916115, 0.824565, 0.82095, 0.81637, 0.81174, 0.80976, 0.8039, 0.75721, 0.756635, 0.755985, 0.702785, 0.6094, 0.579055, 0.55939, 0.50795, 0.49916, 0.49104, 0.45315, 0.45272, 0.441375, 0.431, 0.338225, 0.23515, 0.20846, 0.004405, 0.000815, 0.000815, 0.000815, 0.000685, 0.00067, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000665, 0.000625, 0.000625, 0.000625, 0.000625, 0.000625, 0.000625, 0.000625, 0.000625, 0.000625, 0.00033, 4.5e-05, 4.5e-05, 4.5e-05, 4.5e-05, 0.0]}, {"marker": {"color": "lightsalmon"}, "name": "Test DataSet", "type": "bar", "x": ["tag2", "tag3", "tag41", "tag4", "tag9", "tag6", "tag73", "tag62", "tag61", "tag69", "tag37", "tag36", "tag40", "tag51", "tag5", "tag7", "tag54", "tag8", "tag78", "tag77", "tag52", "tag50", "tag53", "tag79", "tag45", "tag58", "tag59", "tag44", "tag38", "tag16", "tag29", "tag30", "tag28", "tag27", "tag21", "tag26", "tag25", "tag24", "tag23", "tag22", "tag32", "tag20", "tag19", "tag11", "tag10", "tag1", "tag31", "tag39", "tag33", "tag71", "tag68", "tag67", "tag66", "tag65", "tag64", "tag72", "tag74", "tag34", "tag75", "tag76", "tag57", "tag56", "tag55", "tag49", "tag48", "tag47", "tag46", "tag43", "tag42", "tag35", "tag70", "tag63", "tag60", "tag12", "tag15", "tag13", "tag14", "tag17", "tag18", "Unnamed: 0"], "y": [1.0, 1.0, 0.99964, 0.99922, 0.99906, 0.99747, 0.98311, 0.98237, 0.97746, 0.97151, 0.96833, 0.96468, 0.95106, 0.93189, 0.85061, 0.84925, 0.79237, 0.77112, 0.74938, 0.74866, 0.74415, 0.6904, 0.67343, 0.10966, 0.00194, 0.00187, 0.00187, 0.00174, 0.00173, 0.00173, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.00172, 0.0017, 0.00169, 0.00167, 0.00164, 0.00164, 0.00164, 0.00164, 0.00164, 0.0]}],
#                         {"barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"mark ...

# %% [markdown]
# *Видим, что у довольно большого количества признаков очень много пропущеных значений*

# %% [markdown]
# *Порасуждаем на этот счет:*

# %% [markdown]
# *Мы работаем с данными, полученными с определенного набора датчиков, как каком-то из производств. Отсутствие значения в признаке(который является показаниями датчика) может означать, что датчик в данный момент не фиксировал каих-либо действий, так как они не происходили. В то же время, то небольшое количество полученных данных с датчиков, по которым пропусков 99%, может свидетельствовать о наступлении какого-то важного события в производственной цепочке.*

# %% [markdown]
# *Если построение дальнейшей модели мы будем основывать на данном предположении, то выкидывать показания с NaN из таблицы будет категорически не верно.*

# %% [markdown]
# *Так же заменять NaN любой эвристикой (нулями, средними, медианой и тд) можно посчитать плохой стратегией, так как отсутвие значения на датчике означает именно отсутвие значения, а не синтетическую эвристику*

# %% [markdown]
# *Поэтому в дальнейшем нашем анализе и выборе модели будем придерживаться именно такого предположения*

# %% [markdown]
# ***

# %% [markdown]
# #### *Подготовим наши датасеты для модели машинного обучения*

# %% [markdown]
# *Установим признак даты как индекс*

# %%
train.index = pd.DatetimeIndex(train['Unnamed: 0'])
test.index = pd.DatetimeIndex(test['Unnamed: 0'])

# %% [markdown]
# *Удалим признак даты, так как он  стал индексом*

# %%
train = train.drop(['Unnamed: 0'], axis=1)
test = test.drop(['Unnamed: 0'], axis=1)

# %% [markdown]
# *Так же удалим из обучающего датасета события в которых по целевым признакам имеются NaN*

# %%
train = train.dropna(how='all', subset=['target1', 'target2', 'target3', 'target4'])

# %% [markdown]
# *Разобъем обучающий датасет на X и y*

# %%
X_train = train.drop(['target1', 'target2', 'target3', 'target4'], axis=1)
y_train = train[['target1', 'target2', 'target3', 'target4']]

# %% [markdown]
# ***

# %% [markdown]
# #### Модель

# %% [markdown]
# *Для прогнозирования мы будем использовать CatBoostRegressor, как зарекомендовавший себя с хорошей стороны(мной были попробованы другие классификаторы, они оказались хуже чем CatBoost)*

# %% [markdown]
# *Для кросс-валидации применим sklearn.model_selection.TimeSeriesSplit, так как у нас имеется временная последовательность событий*

# %%
tscv = TimeSeriesSplit(n_splits=10)

# %% [markdown]
# *Подберем некторые гиперпараметры*

# %%
param_grid = {'learning_rate': [0.03, 0.06, 0.1], 'depth': [4, 6, 8], 'l2_leaf_reg': [3, 5, 7]}
model = CatBoostRegressor(loss_function='MultiRMSE', nan_mode='Min', silent=True)
grid_search = GridSearchCV(model, param_grid=param_grid, cv=tscv)

# %% [markdown]
# *Обучим модель*

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#              error_score=nan,
#              estimator=<catboost.core.CatBoostRegressor object at 0x000000004BA7AAC8>,
#              iid='deprecated', n_jobs=None,
#              param_grid={'depth': [4, 6, 8], 'l2_leaf_reg': [3, 5, 7],
#                          'learning_rate': [0.03, 0.06, 0.1]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %% [markdown]
# *Обучение заняло сутки(нет GPU)*

# %% [markdown]
# *Посмотрим параметры лучшей модели по результатам решетчатого поиска*

# %%
grid_best_param = grid_search.best_params_
print("Параметры лучшей модели: {}".format(grid_best_param))
# Out:
# Параметры лучшей модели: {'depth': 4, 'l2_leaf_reg': 3, 'learning_rate': 0.03}

# %% [markdown]
# *Посмотрим на лучший результат, по результатам кросс-валидации*

# %%
grid_best_score = grid_search.best_estimator_.best_score_
print("Скор на обучающем наборе: {}".format(grid_best_score))
# Out:
# Скор на обучающем наборе: {'learn': {'MultiRMSE': 0.001283504560946091}}

# %% [markdown]
# *Получим предсказания на тестовом наборе*

# %%
predicted = pd.DataFrame(grid_search.best_estimator_.predict(test), columns=y_train.columns, index=test.index)

# %% [markdown]
# *Сохраним результат в файл*

# %%
predicted.to_csv(r'C:\datasets\ChemTechAI\test_predict.csv')

# %% [markdown]
# ***

# %% [markdown]
# #### Посмотрим на важность признаков

# %% [markdown]
# *Сохраним важность признаков с именами в DataFrame, для удобства анализа*

# %%
feature_imortance_name = pd.DataFrame(data=[grid_search.best_estimator_.feature_names_, 
                                            grid_search.best_estimator_.feature_importances_]).T
feature_imortance_name.columns = ['tags', 'importance']

# %% [markdown]
# *Сохраним топ-10 признаков в отдельный файл*

# %%
feature_imortance_ratio = feature_imortance_name.sort_values(by='importance', ascending=False)
feature_imortance_ratio.head(10).to_csv(r'C:\datasets\ChemTechAI\top10_feature_importance.csv')

# %% [markdown]
# *Построим график на котором отобразим важность признаков в виде столбчатой диаграммы*

# %%
fig = px.bar(feature_imortance_ratio, y='importance', x='tags', text='tags')
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide')
fig.show()
# Out:
# <div>
#
#
#             <div id="afaa7286-4156-43ff-b397-5cc0bd6ec92d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("afaa7286-4156-43ff-b397-5cc0bd6ec92d")) {
#                     Plotly.newPlot(
#                         'afaa7286-4156-43ff-b397-5cc0bd6ec92d',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "tags=%{text}<br>importance=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "text